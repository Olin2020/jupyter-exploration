# %% [markdown]
# <a href="https://colab.research.google.com/github/Olin2020/jupyter-exploration/blob/main/My_First_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# My first markdown cell in Jupyter
#
# # Formatting practice
# This word is *italic* and this word is **bold**.

# %%
print("Hello, World!")
# Out:
# Hello, World!
